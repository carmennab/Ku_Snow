# %%
import pandas as pd
from scipy.stats import pearsonr
import numpy as np
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from matplotlib import gridspec
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### load radar freeboard + snow depth data

# %%
# import snow depth and radar freeboard data from 01/10/2019 - 30/04/2020
snow = np.asarray(Dataset('/Users/carmennab/Dropbox/OI_PolarSnow/EASE/data/ERA5_temp.nc')['Temperature'])[3560:3743]
cs2_cpom = np.asarray(Dataset('/Users/carmennab/Dropbox/OI_PolarSnow/EASE/freeboard_daily_interpolated/CS2_CPOM_full.nc')['Radar Freeboard'][3560:3743])
cs2_larm = np.asarray(Dataset('/Users/carmennab/Dropbox/OI_PolarSnow/EASE/freeboard_daily_interpolated/CS2_LARM_full.nc')['Radar Freeboard'][3560:3743])
cs2s3_cpom = np.asarray(Dataset('/Users/carmennab/Dropbox/OI_PolarSnow/EASE/freeboard_daily_interpolated/CS2S3_CPOM_full.nc')['Radar Freeboard'][3560:3743])
cs2s3_larm = np.asarray(Dataset('/Users/carmennab/Dropbox/OI_PolarSnow/EASE/freeboard_daily_interpolated/CS2S3_LARM_full.nc')['Radar Freeboard'][3560:3743])

days = np.arange(0,len(snow))

# %% [markdown]
# ### calculate regional and pan-arctic anomalies for every satellite

# %%
sats = ['SM-LG','CS2_CPOM','CS2_LARM','CS2S3_CPOM','CS2S3_LARM']

# function to calculate regional means 
def regions_WG(regs):
    WG_mean = []
    WG_c = all_interps.copy()
    for day in days:
        WG_c[day][~np.isin(mask_values, regs)] = np.nan
    for day in days:
        WG_mean.append(np.nanmean(WG_c[day]))
    return(WG_mean)

# function to calculate running mean, where T = np.int(number of days/2)
def runningmean(means,T):
    r=[]
    for i in range(T):
        r.append(np.nanmean(means[0:i+T]))

    for i in range(T,np.size(means)-T):
        r.append(np.nanmean(means[i-T:i+T]))

    for i in range(np.size(means)-T,np.size(means)):
        r.append(np.nanmean(means[i-T:]))

    return r

# %%
# regional anomalies
mask_values = np.load('/Users/carmennab/Dropbox/OI_PolarSnow/EASE/auxiliary/NSIDC_Regions_Mask.npy')
regions = ['Baffin','Greenland','Barents','Kara','Laptev','E. Siberian','Chukchi','Beaufort','Central Arctic']
regs = [6,7,8,9,10,11,12,13,15]

T = 15 # 31-day running mean

snow_anoms = {} ; cs2_cpom_anoms = {} ; cs2_larm_anoms = {} ; cs2s3_cpom_anoms = {} ; cs2s3_larm_anoms = {}
lists = [snow_anoms,cs2_cpom_anoms,cs2_larm_anoms,cs2s3_cpom_anoms,cs2s3_larm_anoms]
data = [snow,cs2_cpom,cs2_larm,cs2s3_cpom,cs2s3_larm]

for count,l in enumerate(lists):
    all_interps = data[count]
    for region, reg in zip(regions, regs):
        dm = regions_WG(reg)
        rm = runningmean(dm,T=15)
        l[region] = np.asarray(runningmean(np.asarray(dm)-np.asarray(rm),T=4))

# %% [markdown]
# ### plot monthly timeseries

# %%
fig = plt.figure(figsize=(17,20))
spec = gridspec.GridSpec(ncols=3, nrows=3, wspace=0.4,hspace=0.2)

colors = ['#b2182b','#2166ac','#f4a582','#6baed6']
months = ['Oct','Nov','Dec','Jan','Feb','Mar']
nums = ['a) ', 'b) ', 'c) ', 'd) ', 'e) ', 'f) ', 'g) ', 'h) ', 'i) ']

days = np.arange(0,31)

for count in np.arange(0,9):
    region = regions[count]
    ax = fig.add_subplot(spec[count])
    ax.set_title(region,pad=10,fontsize=15)
    ax.plot(days,snow_anoms[region][0:31],label = 'Air Temperature',color='red')
    ax.text(0.995, 0.945, nums[count],ha='right',fontsize=15,fontweight='bold',transform=ax.transAxes)

    if count in [0,4]:
        ax.set_ylim(-1.5,1.5)
        ax.set_yticks([-1.5,0,1.5])
    elif count in [1,3,5,6]:
        ax.set_ylim(-2,2)
        ax.set_yticks([-2,0,2])
    elif count == 2:
        ax.set_ylim(-2,2)
        ax.set_yticks([-2,0,2])
    else:   
        ax.set_ylim(-3,3)
        ax.set_yticks([-3,0,3])

    if count == 3:
        ax.set_ylabel('Air Temperature (K)',labelpad=10,fontsize=20)
    ax1 = ax.twinx()
    ax1.plot(days,cs2_cpom_anoms[region][0:31]*100,label = 'Radar Freeboard',color='blue')
    if count in [5,8]:
        ax1.set_ylim(-3.1,3.1)
        ax1.set_yticks([-3,0,3])
    elif count == 1:
        ax1.set_ylim(-2.5,2.5)
        ax1.set_yticks([-2.5,0,2.5])
    else:
        ax1.set_ylim(-2,2)
        ax1.set_yticks([-2,0,2])
    if count == 5:
        ax1.set_ylabel('Radar Freeboard (cm)',labelpad=10,fontsize=20)
    ax1.axhline(0,linestyle='dashed',color='grey')
    if count == 8:
        ax1.plot(days[0],snow_anoms[region][0]*100,label = 'Air Temperature',color='red')
        
        ax1.legend(bbox_to_anchor = (1, 0.14),fontsize=10)
        
        ax.text(-0.625, -0.2, 'Day of Month',ha='right',fontsize=20,transform=ax.transAxes)

plt.rc('font', size=15)
plt.savefig('/Users/carmennab/Dropbox/Apps/Overleaf/Snow Interpolated Freeboards/supp_figs/fb_temp_timeseries.png',bbox_inches = "tight")

# %% [markdown]
# ### calculate regional monthly correlation for every satellite

# %%
days = [np.arange(0,31), # Oct
        np.arange(31,61), # Nov
        np.arange(61,91), # Dec
        np.arange(91,122), # Jan
        np.arange(122,151), # Feb
        np.arange(151,182), # Mar
       ]

def stats():
    fb = l[region][day]
    snow = snow_anoms[region][day]
    mask = ~np.isnan(fb) & ~np.isnan(snow) 
    try:
        rstats = pearsonr(snow[mask],fb[mask])
        r = np.round(rstats[0],decimals=2)
        return(r)
    except:
        r = np.nan

# %%
### regional stats
cs2_cpom_c = {} ; cs2_larm_c = {} ; cs2s3_cpom_c = {} ; cs2s3_larm_c = {}
corrs = [cs2_cpom_c,cs2_larm_c,cs2s3_cpom_c,cs2s3_larm_c]

for l,c in zip(lists[1:],corrs):
    
    for region in regions:
        monthly_stats = []
        for day in days:
            r = stats()
            monthly_stats.append(r)
        c[region]=monthly_stats

# %% [markdown]
# ### create figure

# %%
fig = plt.figure(figsize=(17,15))
spec = gridspec.GridSpec(ncols=3, nrows=3, wspace=0.2,hspace=0.3)

colors = ['#b2182b','#2166ac','#f4a582','#6baed6']
months = ['Oct','Nov','Dec','Jan','Feb','Mar']
nums = ['a) ', 'b) ', 'c) ', 'd) ', 'e) ', 'f) ', 'g) ', 'h) ', 'i) ']

for count in np.arange(0,9):
    region = regions[count]
    ax = fig.add_subplot(spec[count])
    ax.set_title(nums[count]+region,pad=10,fontsize=15)
    for dic,sat,color in zip(corrs,sats[1:],colors):
        ax.plot(months,dic[region],label = sat,color=color,marker="o")
    ax.axhline(0,linestyle='dashed',color='grey')
    ax.set_ylim([-1,1])
    
    if count ==8:      
        ax.legend(bbox_to_anchor = (1.55, 0.4),fontsize=13)
ax.set_yticks([-1,-0.5,0,0.5,1])
plt.rc('font', size=15)
fig.text(0.07, 0.36, 'Linear correlation coefficient', ha='center',fontsize=25,rotation='vertical')
plt.savefig('/Users/carmennab/Dropbox/Apps/Overleaf/Snow Interpolated Freeboards/supp_figs/seasonal_correlations_temp.png',bbox_inches = "tight")
